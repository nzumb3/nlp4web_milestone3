# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data_crawl_ready.csv")
#data = pd.read_csv("data.tsv", sep="\t")

# %%
data.shape
# Out:
# (5541841, 9)

# %%
data.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult startYear endYear runtimeMinutes                    genres
# 0        0      1894      \N              1         Documentary,Short
# 1        0      1892      \N              5           Animation,Short
# 2        0      1892      \N              4  Animation,Comedy,Romance
# 3        0      1892      \N             \N           Animation,Short
# 4        0      1893      \N              1              Comedy,Short

# %%
data = data[data.titleType == "movie"]
data.shape
# Out:
# (507430, 9)

# %%
data = data[data.startYear != "\\N"]
data.shape
# Out:
# (455983, 9)

# %%
data.startYear = data.startYear.astype(int)
data = data[data.startYear > 1990]
data = data[data.startYear < 2019]
data.shape
# Out:
# (246252, 9)

# %%
data[(data.isError) & (data.Plot == "Unspecified Error")].head()
# Out:
#           tconst            primaryTitle  startYear      Genre_1    Genre_2  \
# 3886   tt5246700             How It Ends       2018       Action  Adventure
# 4949   tt6706042         Evil Everywhere       2018       Comedy    Fantasy
# 38856  tt3655414     Cien años de perdón       2016        Crime   Thriller
# 46962  tt6673096  Sealers: One Last Hunt       2016  Documentary       None
#
#       Genre_3               Plot  isError
# 3886    Drama  Unspecified Error     True
# 4949   Horror  Unspecified Error     True
# 38856    None  Unspecified Error     True
# 46962    None  Unspecified Error     True

# %%
data[(data.Plot != "Unspecified Error") & (data.isError == False) & (data.Plot != "TODO")].dropna().head()
# Out:
#       tconst                   primaryTitle  startYear      Genre_1  \
# 0  tt8185182  Long Day's Journey Into Night       2018        Drama
# 1  tt7658384                   The Quietude       2018        Drama
# 3  tt7681126                 The Drum Maker       2018    Biography
# 6  tt7670220              I Am Gary Johnson       2018  Documentary
# 7  tt7681112            Yours in Sisterhood       2018  Documentary
#
#        Genre_2  Genre_3                                               Plot  \
# 0      Mystery     None  A man went back to Guizhou, found the tracks o...
# 1     Thriller     None  Two sisters, as close as they are different, f...
# 3  Documentary  History  Following the triumph and struggles of a Metis...
# 6         None     None  I Am Gary Features compelling footage from the...
# 7      History     None  What might be revealed in the slippery space o...
#
#    isError
# 0    False
# 1    False
# 3    False
# 6    False
# 7    False

# %%
data[(data.isError)].head(10)
# Out:
#        tconst                                   primaryTitle  startYear  \
# 2   tt8185584                  Shino Cannot Say Her Own Name       2018
# 8   tt7987514                    Bill's Thud: A Journey Home       2018
# 12  tt8185412  Kostis Papagiorgis, o Pio Glykos Misanthropos       2018
# 13  tt7986984                              Heavy Metal Bones       2018
# 15  tt8188734                                      Alta Banu       2018
# 19  tt8044700                               Chasing Atlantis       2018
# 31  tt8182884                                  El entusiasmo       2018
# 38  tt8188870                                     Two Wolves       2018
# 42  tt8182826                       Sister Sister: The Movie       2018
# 45  tt7991418                                      Gaja Baja       2018
#
#         Genre_1      Genre_2  Genre_3                 Plot  isError
# 2        Family         None     None  Error getting data.     True
# ...

# %%
data[["primaryTitle", "Plot"]].head()
# Out:
#                     primaryTitle  \
# 0  Long Day's Journey Into Night
# 1                   The Quietude
# 2  Shino Cannot Say Her Own Name
# 3                 The Drum Maker
# 4                          Vivas
#
#                                                 Plot
# 0  A man went back to Guizhou, found the tracks o...
# 1  Two sisters, as close as they are different, f...
# 2                                Error getting data.
# 3  Following the triumph and struggles of a Metis...
# 4                                                NaN
